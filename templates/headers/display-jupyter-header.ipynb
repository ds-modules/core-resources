# %%
from IPython.display import Image
Image(filename='jupyter-header-1.png')

# %%
Image(filename='jupyter-header-2.png')

# %%
Image(filename='jupyter-header-3.png')

# %%
Image(filename='jupyter-header-4.png')
